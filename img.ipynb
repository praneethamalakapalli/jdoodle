# %% [markdown]
# <a href="https://colab.research.google.com/github/praneethamalakapalli/jdoodle/blob/main/img.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget '/content/allu.jfif'
# Out:
# /content/allu.jfif: Scheme missing.

# %%
#importing the libaries that for image process
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('/content/allu.jfif')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (710, 474, 3)

# %%
img.shape
# Out:
# (710, 474, 3)

# %%
img
# Out:
# array([[[146, 148, 147],
#         [145, 147, 146],
#         [144, 146, 145],
#         ...,
#         [161, 162, 156],
#         [166, 167, 161],
#         [166, 167, 161]],
#
#        [[145, 147, 146],
#         [144, 146, 145],
#         [143, 145, 144],
#         ...,
#         [160, 161, 155],
#         [165, 166, 160],
#         [165, 166, 160]],
#
#        [[143, 145, 144],
#         [142, 144, 143],
#         [141, 143, 142],
#         ...,
#         [158, 159, 153],
#         [163, 164, 158],
#         [163, 164, 158]],
#
#        ...,
#
#        [[ 26,  26,  26],
#         [ 10,  10,  10],
#         [  5,   5,   5],
#         ...,
#         [ 16,  16,  16],
#         [  0,   0,   0],
#         [ 17,  17,  17]],
#
#        [[ 52,  52,  52],
#         [ 19,  19,  19],
#         [ 10,  10,  10],
#         ...,
#         [ 16,  16,  16],
#         [ 25,  25,  25],
#         [ 53,  53,  53]],
#
#        [[ 66,  66,  66],
#         [ 18,  18,  18],
#         [  7,   7,   7],
# ...

# %%
#display the image from numpy array
img_plot=plt.imshow(img)
plt.show()

# %%
#resizing the image using pillow library
from PIL import Image

# %%
img=Image.open('/content/allu.jfif')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x710 at 0x7C7C2BC58C70>

# %%
img_resized=img.resize((200,200))

# %%
img_resized
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7C7C2BFFACE0>

# %%
img_resized.save('/content/allu.jfif')

# %%
img_res=mpimg.imread('/content/allu.jfif')
imp_plot=plt.imshow(img_resized)
plt.show()

# %%
img_res.shape
# Out:
# (200, 200, 3)

# %%
#convert rgb into grayscale using open cv
import cv2

# %%
img=cv2.imread('/content/allu.jfif')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
grayscale_image
# Out:
# array([[137, 144, 146, ..., 158, 159, 160],
#        [147, 142, 138, ..., 158, 159, 159],
#        [140, 135, 138, ..., 157, 158, 159],
#        ...,
#        [ 13,  12,  10, ...,  15,  15,  15],
#        [ 13,  12,  10, ...,  16,  16,  17],
#        [ 13,  12,  10, ...,  17,  17,  18]], dtype=uint8)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7C7C2BC28850>

# %%
cv2.imwrite('/content/allu.jfif')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-068d2c563a8c> in <cell line: 1>()
# ----> 1 cv2.imwrite('/content/allu.jfif')
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'imwrite'
# > Overload resolution failed:
# >  - imwrite() missing required argument 'img' (pos 2)
# >  - imwrite() missing required argument 'img' (pos 2)
